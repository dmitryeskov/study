# %%
1. Типы сокетов
•	Stream Sockets (SOCK_STREAM): Обеспечивают надежную, ориентированную на соединение передачу
данных с использованием протокола TCP.
•	Datagram Sockets (SOCK_DGRAM): Предоставляют передачу данных без установления соединения с
использованием протокола UDP, который не гарантирует доставку пакетов.
2. Создание и настройка сокета

# %%
import socket

s_tcp = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s_udp = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)

# %%
3. Привязка и прослушивание
Для серверных приложений необходимо привязать сокет к адресу и порту:

# %%
server_address = ('localhost', 8080)
s_tcp.bind(server_address)
s_tcp.listen(5)

# %%
4. Подключение к серверу
Клиентские приложения используют метод connect для установления соединения с сервером:

# %%
s_tcp.connect(server_address)

# %%
5. Прием и передача данных
•	Отправка данных:

# %%
message = "Hi"
s_tcp.sendall(message.encode('utf-8'))
s_udp.sendto(message.encode('utf-8'), server_address)

# %%
•	Прием данных:

# %%
data = s_tcp.recv(1024)
data, addr = s_udp.recvfrom(1024)

# %%
6. Закрытие соединения
Важно корректно закрывать сокет после завершения работы:

# %%
s_tcp.close()

# %%
7. Обработка исключений
Сетевые операции подвержены различным ошибкам, поэтому рекомендуется использовать 
блоки try-except для обработки исключений:

# %%
try:
    s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
    s.connect(('localhost', 8080))
    s.sendall(b'hi')
except socket.error as e:
    s.close()

# %%
8. Параллельная обработка соединений
Для серверных приложений, чтобы одновременно обслуживать несколько клиентов, используются потоки или процессы:
•	Потоки:

# %%
import threading

def handle_client(client_socket):
    request = client_socket.recv(1024)
    client_socket.close()

while True:
    client_socket, addr = s_tcp.accept()
    client_handler = threading.Thread(target=handle_client, args=(client_socket,))
    client_handler.start()

# %%
•	Процессы:

# %%
import multiprocessing
def handle_client(client_socket):
    request = client_socket.recv(1024)
    client_socket.close()

while True:
    client_socket, addr = s_tcp.accept()
    client_handler = multiprocessing.Process(target=handle_client, args=(client_socket,))
    client_handler.start()

# %%
9. Проблемы безопасности
•	Защита от атак: Ограничение числа подключений, использование брандмауэров.
•	Шифрование: Использование SSL/TLS для шифрования данных, передаваемых по сети.
10. Оптимизация и отладка
•	Логирование: Ведение журналов для отслеживания активности и ошибок.
•	Профилирование: Измерение производительности и устранение узких мест.

# %%
9.1 websocket
import asyncio
import websockets

async def echo(websocket, path):
    try:
        async for message in websocket:
            print(message)
            await websocket.send("echo")
    except websocket.exceptions.ConnectionClosed:
        pass

async def main():
    async with websockets.serve(echo, 'localhost', 7676)
    await asyncio.Future()

asyncio.run(main())
        


import asyncio
import websockets

async def send_message():
    uri = "ws://localhost:7676"

    async with websockets.connect(url) as websocket:
        await websocket.send("dgdrfg")
        response = await websocket.recv()

asyncio.run(send_message())

# %%
TCP Клиент-Сервер
Сервер (TCP)

# %%
import socket

server_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
server_socket.bind(('localhost', 8080))
server_socket.listen(5)

while True:
    client_socket, addr = server_socket.accept()
    data = client_socket.recv(1024)
    response = "sdfg"
    client_socket.sendall(response.encode('utf-8'))
    client_socket.close()

# %%
Клиент (TCP)

# %%
import socket

client_socket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
client_socket.connect(('localhost', 8080))
res = client_socket.recv()
client_socket.close()

# %%
UDP Клиент-Сервер
Сервер (UDP)

# %%
import socket

server_socket = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
server_socket.bind(('localhost', 8080))

while True:
    data, addr = server_socket.recvfrom(1024)
    response = "sxdfg"
    server_socket.sendto(response.encode('urtf-8'), addr)

# %%
Клиент (UDP)

# %%
import socket

client_socket = socket.socket(socket.AF_INET, socket.SOCK_DGRAM)
message = 'sdf'
client_socket.sendto(message.encode('utf-8'))
client_socket.close()

# %%
Ключевые отличия TCP и UDP
•	TCP:
o	Обеспечивает надежную доставку данных.
o	Использует установку соединения (трехстороннее рукопожатие).
o	Гарантирует порядок доставки пакетов.
o	Используется для приложений, где важна целостность данных (например, HTTP, FTP).
•	UDP:
o	Не требует установки соединения.
o	Быстрее, но не гарантирует доставку данных.
o	Пакеты могут прийти в любом порядке.
o	Используется для приложений, где важна скорость и не критична потеря данных (например, видеоконференции, игры).
Обе реализации имеют свои особенности и могут быть адаптированы под конкретные требования вашего приложения.

# %%
HTTP 1.1, HTTP 2, QUIC/HTTP 3;
HTTP (HyperText Transfer Protocol) — это основной протокол, используемый для передачи данных в вебе.
Существует несколько версий HTTP, каждая из которых улучшала предыдущие версии, чтобы обеспечить
лучшую производительность, безопасность и надежность. Рассмотрим HTTP 1.1, HTTP/2 и HTTP/3 (основанный на QUIC).
HTTP 1.1
HTTP 1.1 был введен в 1997 году как улучшение оригинального HTTP 1.0. Основные улучшения включают:
•	Постоянные соединения (Persistent Connections): Позволяют использовать одно TCP-соединение для 
нескольких запросов/ответов, что уменьшает накладные расходы на установку новых соединений.
•	Частичные запросы (Range Requests): Позволяют клиентам запрашивать определенные части документа,
что полезно для возобновления прерванных загрузок.
•	Кэширование: Расширенные заголовки для управления кэшированием, такие как Cache-Control, ETag и If-Modified-Since.
•	Сжатие заголовков: Использование заголовка Transfer-Encoding: chunked для передачи данных частями, 
что улучшает передачу больших объемов данных.

# %%
Пример простого HTTP 1.1 запроса:

# %%
import http.client

conn = http.client.HTTPConnection("www.test.de")
conn.request("GET","/")
response = conn.getresponse()
data = response.read()
conn.close()

import requests
response = requests.get("http://www.test.de")

# %%
HTTP/2
HTTP/2 был стандартизирован в 2015 году и включает множество улучшений по сравнению с HTTP 1.1:
•	Бинарный протокол: HTTP/2 использует бинарный формат вместо текстового, что делает парсинг более эффективным.
•	Мультиплексирование: Позволяет отправлять несколько запросов и ответов через одно TCP-соединение одновременно, 
что устраняет проблему блокировки «головы линии» (Head-of-Line Blocking).
•	Сжатие заголовков (HPACK): Сокращает размер заголовков, что уменьшает накладные расходы.
•	Приоритеты и потоки: Клиенты могут назначать приоритеты для запросов, что позволяет серверам лучше управлять ресурсами.
•	Серверные пуши: Сервер может отправлять ресурсы клиенту без ожидания явного запроса, что ускоряет загрузку страниц.
Пример простого HTTP/2 запроса:

# %%
import httpx
import asyncio
import nest_asyncio

nest_asyncio.apply()

async def main():
    try:
        async with httpx.AsyncClient(http2=True) as client:
            response = await client.get("https://www.test.de")
            print(response.status_code)
            print(response.text)
    except httpx.RequestError as exc:
        print("error")

await main()
# Out:
# 200
# <!doctype html>
# <html lang="de" class="no-js no-scroll-x" data-cms-link="cms://ps4/OverviewPageBase/default/?pool=online">
#
# <head>
# 	<meta charset="utf-8">
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge" />
# 	<meta name="viewport" content="width=device-width, initial-scale=1" />
# 	<title>Stiftung Warentest | Unabh&#228;ngig. Objektiv. Unbestechlich.</title>
# 	<meta name="description" lang="de" content="Stiftung Warentest: Testberichte zu Elektronik, Haushalt und Gesundheit sowie Finanzen, Versicherung und Steuern" />
# 	<meta name='robots' content="index,follow,noarchive,max-snippet:-1,max-image-preview:large,max-video-preview:-1" />
# 	<meta name="theme-color" content="#414141">
# 	<link rel="canonical" href="https://www.test.de/" />
#
# 	<link rel="preload" href="https://cdn.test.de/static/fonts/thebestvar;v128175272.woff2" as="font" type="font/woff2" crossorigin>
# 	<link rel="preload" href="https://cdn.test.de/static/fonts/theantiquabvar-subset;v128175272.woff2" as="font" type="font/woff2" crossorigin>
#
# 	<style>/*critical*/ :root{--color-orange:#ff5200;--color-orange-medium:#ff7c4c;--color-orange-middle-dark:#d94500;--color-orange-dark:#db3a00;--color-orange-reddish:#bf3d00;--color-petrol:#417d8c;--color-petrol-light:#eaf4f8;--color-petrol-middle:#076a83;--color-petrol-dark:#055063;--color-brown-warm-light:#f6efe6;--color-yellow-light:#fffebd;--color-yellow-bright:#fff000;--color-yellow-dark:#ffd341;--color-turquoise-bright:#6fffdd;--color-blue-light:#d5faff;--color-blue-bright:#006bb6;--color-blue-medium:#004b80;--color-blue-dark:#043253;--color-white:#fff;--color-black:#121212;--color-dark-black:#000;--color-green:#007562;--color-green-bright:#d9ebc8;--color-green-light:#eaf6e1;--color-green-brighter:#d9eae7;--color-red-bright:#f7dce0;--color-red-light:#f2dbe0;--color-red:#cc122e;--color-grey-brand:#666;--color-brand-test:#e80044;--color-brand-finance:#006dcc;--color-brand-finance-disabled:rgba(0,109,204,.5);--color-brand-app-test:#db083c;--color-brand-app-finance:#0076bd;--color-grey-80:#393a3b;--color-grey-60:#6b6d6e;--color-grey-40:#9d9fa1;--color-grey-20:#cfd2d4;--color-grey-10:#e3e6e8;--color-grey-5:#f4f6f8;--color-yellow-100:#ffe400;--color-yellow-65:#ffed59;--color-yellow-50:#fff28c;--color-yellow-30:#fff6b2;--color-yellow-15:#fffbd9;--color-text:var(--color-black);--color-text-hover:var(--color-petrol-middle);--color-link:var(--color-black);--color-text-link:var(--color-petrol-dark);--color-feedback-green:var(--color-green);--color-feedback-red:var(--color-red);--color-filter-tag-ative:var(--color-petrol-dark);--color-filter-tag-hover:#cde1e6;--color-overlay:rgba(0,0,0,.6);--color-overlay-little:rgba(0,0,0,.2);--color-overlay-white:hsla(0,0%,100%,.6);--color-border:var(--color-grey-20);--color-border--side-nav:rgba(50,50,50,.3);--color-form-focus-input:rgba(7,106,131,.2);--color-form-hover-light:rgba(5,80,99,.3);--color-form-hover-dark:#83a9b2;--color-shadow:rgba(0,0,0,.15);--color-shadow-lighter:rgba(0,0,0,.08);--color-shadow-middle:rgba(0,0,0,.2);--color-shadow-darker:rgba(0,0,0,.25);--color-error-box:rgba(168,11,47,.15);--color-button-blue-light:#bcdfe8;--color-shop-gradient-light:#d9ecf1;--color-shop-gradient-dark:#b7e0e0;--breakpoint-tablet-min:48rem;--breakpoint-desktop-min:64rem;--content-max-width-inner:77.75rem;--content-max-width:82.75rem;--editorial-content-max-width:56rem;--padding-by-viewport:calc((100vw - var(--content-max-width-inner))/2);--width-viewport:calc(100vw - var(--width-scrollbar, 0px));--footer-reduced-tablet-max-height:calc(var(--space-m)*2 + var(--line-height-text-xsmall)*2);--main-reduced-min-height:calc(var(--height-available, 100dvh) - var(--header-height) - var(--footer-reduced-tablet-max-height));--height-vieport:min(100dvh,var(--height-available,100dvh));--space-6xs:0.25rem;--space-5xs:0.5rem;--space-4xs:0.75rem;--space-3xs:1rem;--space-xxs:1.25rem;--space-xs:1.5rem;--space-s:1.75rem;--space-m:2rem;--space-l:2.25rem;--space-xl:2.5rem;--space-xxl:2.75rem;--space-3xl:3rem;--space-4xl:3.25rem;--space-5xl:3.5rem;--space-6xl:3.75rem;--space-7xl:4rem;--space-module-bottom:var(--space-xl);--space-module-bottom-l:var(--space-xl);--space-module-bottom-s:var(--space-xs);--space-module-bottom-xs:var(--space-xs);--space-module-bottom-xs-static:var(--space-xs);--space-module-bottom-xxs:var(--space-3xs);--space-text-bottom:var(--space-xs)}@media (min-width:48rem){:root{--space-module-bottom:var(--space-3xl);--space-module-bottom-l:var(--space-3xl);--space-module-bottom-s:var(--space-l);--space-module-bottom-xs:var(--space-m)}}@media (min-width:64rem){:root{--space-module-bottom:var(--space-3xl);--space-module-bottom-l:var(--space-6xl);--space-module-bottom-s:var(--space-xl);--space-module-bottom-xs:var(--space-xl);--space-text-bottom:var(--space-m)}}:root{--column-count:4;--width-gutter:var(--space-xxs);--full-content-width:min(calc(var(--width-viewport) - var(--width-gutter)*2),calc(var(--content-max-width) - var(--width-gutter)*2));--full-gutter-width:calc(var(--width-gutter)*(var(--column-coun ...
#
# /*! normalize.css v8.0.1 | MIT License | github.com/necolas/normalize.css */html{-webkit-text-size-adjust:100%;line-height:1.15}body{margin:0}main{display:block}h1{font-size:2em;margin:.67em 0}hr{box-sizing:content-box;height:0;overflow:visible}pre{font-family:monospace,monospace;font-size:1em}a{background-color:transparent}abbr[title]{border-bottom:none;text-decoration:underline;-webkit-text-decoration:underline dotted currentColor;text-decoration:underline dotted currentColor}b,strong{font-weight:bolder}code,kbd,samp{font-family:monospace,monospace;font-size:1em}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sub{bottom:-.25em}sup{top:-.5em}img{border-style:none}button,input,optgroup,select,textarea{font-family:inherit;font-size:100%;line-height:1.15;margin:0}button,input{overflow:visible}button,select{text-transform:none}[type=button],[type=reset],[type=submit],button{-webkit-appearance:button}[type=button]::-moz-focus-inner,[type=reset]::-moz-focus-inner,[type=submit]::-moz-focus-inner,button::-moz-focus-inner{border-style:none;padding:0}[type=button]:-moz-focusring,[type=reset]:-moz-focusring,[type=submit]:-moz-focusring,button:-moz-focusring{outline:1px dotted ButtonText}fieldset{padding:.35em .75em .625em}legend{box-sizing:border-box;color:inherit;display:table;max-width:100%;padding:0;white-space:normal}progress{vertical-align:baseline}textarea{overflow:auto}[type=checkbox],[type=radio]{box-sizing:border-box;padding:0}[type=number]::-webkit-inner-spin-button,[type=number]::-webkit-outer-spin-button{height:auto}[type=search]{-webkit-appearance:textfield;outline-offset:-2px}[type=search]::-webkit-search-decoration{-webkit-appearance:none}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}details{display:block}summary{display:list-item}[hidden],template{display:none}html{box-sizing:border-box}*,:after,:before{box-sizing:inherit}details>*{box-sizing:border-box}.focus-visible{outline:2px solid currentcolor}:focus-visible{outline:2px solid currentcolor}:focus{scroll-margin-top:var(--header-height)}.header-is-sticky :focus{scroll-margin-top:var(--header-height-sticky)}html{background-color:var(--color-grey-80);color:var(--color-black);font-family:var(--font-family-thebest);font-size:1rem;line-height:1.5rem;overflow-y:scroll;scroll-padding-bottom:1rem;scroll-padding-top:calc(var(--header-height-sticky) + var(--scroll-margin-space))}.scroll-up{scroll-padding-top:calc(var(--header-height) + var(--portal-navigation-desktop-height) + var(--scroll-margin-space))}.has-tango-tab-navigation{scroll-padding-top:calc(var(--tango-tab-navigation-height) + var(--scroll-margin-space))}.no-scroll-padding{scroll-padding-top:0}.no-scroll-x body{overflow-x:hidden}.no-scroll-y{overflow-y:hidden}abbr,abbr[title]{text-decoration:none}em{font-style:normal}@media (max-width:41.1875rem){.scroll-up:not(.has-tango-tab-navigation){scroll-padding-top:calc(var(--header-height) + var(--search-bar-height) + var(--scroll-margin-space))}}input[type=search]{-webkit-appearance:none;-moz-appearance:none;appearance:none}input[type=search]::-webkit-search-cancel-button,input[type=search]::-webkit-search-decoration,input[type=search]::-webkit-search-results-button,input[type=search]::-webkit-search-results-decoration{display:none}input[type=search]:focus{font-size:100%;outline:none}input:-webkit-autofill,input:-webkit-autofill:focus,input:-webkit-autofill:hover{-webkit-text-fill-color:var(--color-text);-webkit-box-shadow:0 0 0 62.5rem var(--color-white) inset;-webkit-transition:background-color 5000s ease-in-out 0s;transition:background-color 5000s ease-in-out 0s}.js-input-label input:-webkit-autofill{animation-name:animation-onAutoFillStart}.js-input-label input:not(:-webkit-autofill){animation-name:animation-onAutoFillCancel}@keyframes animation-onAutoFillStart{0%{visibility:visible}to{visibility:visible}}@keyframes animation-onAutoFillCancel{0%{visibility:visible}to{visibility:visible}}.h1,.h2,.h3 ...
# 	<style>/*module/tabnavigation*/ .tab-navigation{height:0;width:0}.tab-navigation__link{display:block;height:0;left:0;overflow:hidden;position:absolute;white-space:nowrap}.tab-navigation__link:focus{background:var(--color-white);height:auto;outline:none;padding:var(--space-4xs) var(--space-xxs);z-index:var(--z-tab-navigation)}</style>
# 	<style>/*module/header*/ .header-wrapper{--translate-y-value:0;--translate:min(0,var(--translate-y-value));position:sticky;top:0;transform:none;transition:height var(--sticky-transition-time);will-change:height;z-index:var(--z-header)}.header-wrapper--transform{transform:translateY(calc(1px*var(--translate)))}.header{background:var(--color-orange);color:var(--color-white);display:flex;height:var(--header-height);justify-content:center;max-width:100%;padding:0;position:relative;transition:height var(--sticky-transition-time);width:100%}.header-is-sticky .header--shadow{box-shadow:0 .375rem 1.875rem var(--color-shadow)}.redaktionsmodul-toggle.is-open~.page .header{position:sticky}.sticky.header{height:var(--header-height-sticky);transition:height var(--sticky-transition-time)}.header__print-logo{display:none}.header:before{background:var(--color-grey-brand);content:"";height:var(--header-height);left:0;position:absolute;top:0;width:10%}.header:before,.sticky.header:before{transition:height var(--sticky-transition-time)}.sticky.header:before{height:var(--header-height-sticky)}.header__content{display:flex;justify-content:flex-start;padding:0;width:100%}.header__button{background:0;border:0;bottom:0;cursor:pointer;height:1.5rem;margin:0;opacity:1;padding:0;position:absolute;right:var(--space-3xs);top:50%;transform:translateY(-50%);width:1.5rem}.header__button.focus-visible{outline:2px var(--color-white) solid}.header__button:focus-visible{outline:2px var(--color-white) solid}.header__button .icon--menu{margin-right:0;top:0}.header__logo .icon--header-logo{display:none}.header__logo .icon--header-logo-small{height:var(--header-height);transition:height var(--sticky-transition-time),width var(--sticky-transition-time)}.sticky .header__logo .icon--header-logo-small:not(.sticky .side-nav .header__logo .icon--header-logo-small){height:var(--header-height-sticky);transition:height var(--sticky-transition-time),width var(--sticky-transition-time)}.header__logo.focus-visible:before{border:2px solid var(--color-white);content:"";height:100%;position:absolute;width:100%}.header__logo:focus-visible:before{border:2px solid var(--color-white);content:"";height:100%;position:absolute;width:100%}.header__logo{display:block;opacity:1}.header__logo.focus-visible{outline:none;position:relative}.header__logo:focus-visible{outline:none;position:relative}.header__logo-wrapper{margin:0;max-width:10.375rem;opacity:1;width:100%;z-index:var(--z-header-logo)}.header__sticky-search{background:0;border:none;display:none;margin:0;opacity:0;padding:0;position:absolute;right:var(--space-6xl);top:50%;transform:translateY(-50%);transition:opacity var(--sticky-transition-time)}.header__sticky-search .icon--search{top:0}.sticky .header__sticky-search{cursor:pointer;display:block;opacity:1;transition:opacity var(--sticky-transition-time)}.header .visually-hidden{height:1px;left:-625rem;overflow:hidden;position:absolute;top:auto;width:1px}.header__button--desktop{display:none}@media (max-width:47.9375rem){.main-navigation__search-bar-wrapper{display:none}}@media (min-width:48rem){.header,.header:before{height:var(--header-height)}.header__content{max-width:var(--full-content-width)}.sticky .header__sticky-search{display:none}.header__logo-wrapper{margin-left:calc(var(--width-gutter)*-1);max-width:10.5rem}.icon--header-logo-small{display:none}.header__logo .icon--header-logo{display:block;height:var(--header-height);transition:height var(--sticky-transition-time),width var(--sticky-transition-time)}.sticky .header__logo .icon--header-logo:not(.sticky .side-nav .header__logo .icon--header-logo){height:var(--header-height-sticky);transition:height var(--sticky-transition-time),width var(--sticky-transition-time)}.main-navigation__search-bar-wrapper{display:block}.main-navigation__portal-navigation-wrapper{display:none}}@media (min-width:64rem){.header{padding:0}.header:before{width:calc(50% - var(--full-content-width) + var(--full-content-width)/2 + 9.6875rem)}.header_ ...
# 	<style>/*module/mainnavigation*/ .main-navigation{--main-navigation-space:var(--space-4xl);display:flex;flex-wrap:nowrap;justify-content:space-evenly;margin:0;padding:0 var(--main-navigation-space) 0 0;width:100%}.main-navigation__item{align-self:center;color:var(--color-white);cursor:pointer;height:100%;list-style:none;margin:0;opacity:1;padding:0}.main-navigation__item--abo,.main-navigation__item--shop{margin-left:.875rem}.main-navigation__link{color:var(--color-white);cursor:pointer;height:100%;justify-content:center}.sticky .main-navigation__link{opacity:0;pointer-events:none;transition:opacity var(--sticky-transition-time)}.main-navigation__link-text{font-size:var(--header-font-size);font-weight:700;line-height:var(--header-font-size);white-space:nowrap}.main-navigation__link--top-nav{align-items:center;display:flex;flex-direction:column;padding-left:var(--space-3xs);position:relative;text-decoration:none}.main-navigation__link--top-nav.focus-visible{color:var(--color-white);outline:none;position:relative}.main-navigation__link--top-nav:focus-visible{color:var(--color-white);outline:none;position:relative}.main-navigation__link--top-nav.focus-visible:before{border:2px solid var(--color-white);content:"";height:100%;left:-.3125rem;position:absolute;width:calc(100% + .625rem)}.main-navigation__link--top-nav:focus-visible:before{border:2px solid var(--color-white);content:"";height:100%;left:-.3125rem;position:absolute;width:calc(100% + .625rem)}.is-active .main-navigation__link:after,.main-navigation__link--top-nav:hover:after,.main-navigation__link:active:after{background:var(--color-white);border-bottom:var(--space-6xs) solid var(--color-white);bottom:0;content:"";height:var(--space-6xs);position:absolute;width:100%}.main-navigation__link--top-nav:hover{color:var(--color-white)}.is-active .main-navigation__link,.main-navigation__link:active,.main-navigation__link:focus,.main-navigation__link:hover{text-decoration:none}.main-navigation__item--cart,.main-navigation__item--login{display:none}.main-navigation__item--search{color:var(--color-text);height:var(--search-bar-height);left:0;margin:0 auto;position:absolute;right:0;top:var(--header-height);z-index:var(--z-header-search)}.main-navigation__item .icon--book{height:var(--space-xs);width:var(--space-3xs)}.main-navigation__item .icon--add{height:var(--space-xs);margin-right:0;width:var(--space-xxs)}.main-navigation__item--abo .main-navigation__link-text--long{display:none}.main-navigation__item--abo .main-navigation__link-text--short{display:block}@media screen and (min-width:30rem){.main-navigation__item--search{margin-right:auto}}@media (max-width:47.9375rem){.main-navigation{justify-content:flex-end;margin-left:.5rem}.main-navigation__link--top-nav{padding-left:0}}@media (min-width:48rem){.main-navigation__item--search{margin-right:var(--space-3xs);position:relative;top:auto}.main-navigation__item--abo,.main-navigation__item--shop{margin-left:var(--space-xxs)}.main-navigation__item .icon--book{height:var(--space-xxs);margin-bottom:var(--space-6xs);width:var(--space-xxs)}.main-navigation__link--top-nav.focus-visible:before{left:.5rem;width:100%}.main-navigation__link--top-nav:focus-visible:before{left:.5rem;width:100%}}@media (min-width:64rem){.main-navigation{padding-right:0}.main-navigation__item--search{margin-right:auto}.main-navigation__item--abo,.main-navigation__item--cart,.main-navigation__item--login,.main-navigation__item--shop{opacity:1;transition:opacity var(--sticky-transition-time)}.main-navigation__item--abo{margin-right:var(--space-xxs)}.main-navigation__link--top-nav{padding:0}.main-navigation__item--abo .main-navigation__link-text--long{display:block}.main-navigation__item--abo .main-navigation__link-text--short{display:none}.main-navigation__link--top-nav.focus-visible:before{left:-.3125rem;width:calc(100% + .625rem)}.main-navigation__link--top-nav:focus-visible:before{left:-.3125rem;width:calc(100% + .625rem)}}@media (min-width:80rem){.main-navigatio ...
# 	<style>/*module/userstatus*/ .user-status__watch{align-content:center;background:var(--color-petrol-dark);border-radius:100%;font-size:var(--font-size-watch-list);font-weight:700;height:var(--space-3xs);justify-content:center;line-height:var(--font-size-watch-list);place-content:center;position:absolute;right:-.25rem;top:40%;transform:translateY(-50%);width:var(--space-3xs)}.user-status__watch--hidden{display:none}.user-status__watch--show{display:grid}.user-status__item{list-style:none;margin:0;padding:0}.user-status__item,.user-status__link{color:var(--color-white);display:flex;height:100%}.user-status__link{align-items:center;cursor:pointer;flex-direction:column;justify-content:center;padding-left:var(--space-3xs);position:relative;text-decoration:none;transition:all var(--transition-time)}.user-status__link.focus-visible{color:var(--color-white);outline:none;position:relative}.user-status__link:focus-visible{color:var(--color-white);outline:none;position:relative}.user-status__link.focus-visible:before{border:2px solid var(--color-white);content:"";height:100%;position:absolute;width:100%}.user-status__link:focus-visible:before{border:2px solid var(--color-white);content:"";height:100%;position:absolute;width:100%}.user-status__item--cart .user-status__link:active:after,.user-status__item--cart.is-active .user-status__link:after{background:var(--color-white);border-bottom:var(--space-6xs) solid var(--color-white);bottom:0;content:"";height:var(--space-6xs);position:absolute;width:100%}.user-status__link .icon--user-new-svg{height:1.375rem;width:1.375rem}.user-status__link .icon--shopping-cart-svg{margin-top:.25rem}.user-status__link:hover{text-decoration:none}.user-status__item--cart{display:none}.sticky .user-status__item--cart-sticky{display:flex;margin-top:2px}.sticky .user-status__item--cart-sticky .user-status__link{padding:0}.user-status__item--login{margin-left:.875rem;width:-moz-max-content;width:max-content}.user-status__link--login,.user-status__link--mytest{fill:var(--color-white);background-color:var(--color-orange-middle-dark);color:var(--color-white);padding:0 .5rem;width:-moz-max-content;width:max-content}.user-status--is-open .user-status__link--mytest{fill:var(--color-orange-dark);background-color:var(--color-white);color:var(--color-orange-dark)}.is-logged-in .user-status__item--login .user-status__link--login,html:not(.is-logged-in) .user-status__item--login .user-status__link--mytest{display:none}.user-status__text{font-size:var(--header-font-size);font-weight:700;line-height:var(--header-font-size)}.sticky .user-status__text{display:none}.user-status--is-open .user-status__link .user-status__text{color:var(--color-orange-dark)}.user-status-nav__item--logout .link{font-weight:400;min-height:0;min-height:auto;text-decoration:none}@media (hover:hover){.user-status__link:hover{color:var(--color-white)}.user-status__item--cart .user-status__link:hover:after{background:var(--color-white);border-bottom:var(--space-6xs) solid var(--color-white);bottom:0;content:"";height:var(--space-6xs);position:absolute;width:100%}.user-status--is-open .user-status__link--mytest:hover{fill:var(--color-orange-dark);color:var(--color-orange-dark)}.user-status__item--login:not(.user-status--is-open) .user-status__link:hover{background-color:var(--color-orange-reddish);transition:none}}@media (max-width:47.9375rem){.user-status__item--login .icon{width:1.25rem}.sticky .user-status__item--login{opacity:0;pointer-events:none;transition:opacity var(--sticky-transition-time)}.user-status__watch{top:30%}}@media (min-width:48rem){.user-status__item--login{margin-left:var(--space-xxs)}.user-status__watch--hidden{display:none}.user-status__watch--show{display:grid}}@media (min-width:64rem){.user-status__item{align-self:center;color:var(--color-white);list-style:none;margin:0;opacity:1;padding:0;transition:all var(--transition-time)}.user-status__item--cart,.user-status__item--login{display:flex;position:relative}.user-status__item--car ...
# 	<style>/*module/sidenavigation*/ .side-nav__wrapper{background:none;content-visibility:auto;height:100%;max-width:100%;position:fixed;right:0;top:0;transition:background var(--transition-time) ease var(--transition-delay),width .1s .75s;width:0;z-index:var(--z-side-navigation)}.side-nav__layer-login{background:var(--color-white);bottom:0;display:flex;left:100%;list-style:none;margin:0;opacity:0;padding:var(--space-3xs) var(--space-xxs);position:sticky;transition:opacity var(--transition-time);width:0;z-index:var(--z-side-navigation-login)}.side-nav--open .side-nav__layer-login{left:0;opacity:1;transition:opacity var(--transition-time);width:100%}.is-logged-in .side-nav__layer-login,.side-nav--sub-menu-open .side-nav__layer-login{display:none}.side-nav__layer-item{flex:1 1 50%}.side-nav__layer-item .link--login,.side-nav__layer-item .link--register{width:100%}.side-nav__layer-item .link--login{color:var(--color-white)}.side-nav__wrapper--visible{background:var(--color-overlay);display:block;transition:background var(--transition-time) ease;width:100%}.side-nav{background:var(--color-white);color:var(--color-text);height:100%;margin-left:100%;overflow:auto;transition:margin-left var(--transition-time);visibility:hidden;width:0}.tango-tab-navigation-is-sticky .side-nav{display:none}.side-nav--open{margin-left:0;overflow-x:hidden;visibility:visible;width:100%}.side-nav__head{background-color:var(--color-orange);display:flex;flex-direction:column;position:sticky;top:0;width:100%;z-index:var(--z-side-navigation-head)}.side-nav__head-inner{height:var(--header-height);position:relative}.side-nav__button{background:0;border:0;bottom:0;cursor:pointer;height:1.5rem;margin:0;padding:0;position:absolute;right:var(--width-gutter);top:50%;transform:translateY(-50%);width:1.5rem}.side-nav__button.focus-visible{outline:2px var(--color-white) solid}.side-nav__button:focus-visible{outline:2px var(--color-white) solid}.side-nav__button .icon--close{margin-right:0;top:0}.side-nav__menu{display:none}.side-nav--open .side-nav__menu{background:var(--color-white);display:block;list-style:none;padding:var(--space-xxs) var(--space-xxs) 0;position:relative}.side-nav--sub-menu-open .side-nav__menu{padding-top:var(--space-6xl)}.side-nav__menu-main{list-style:none;margin:0;padding:0}.side-nav__item{font-size:var(--font-size-text-small);line-height:var(--line-height-text-small);padding:0 0 var(--space-xxs) var(--space-3xs)}.side-nav__item--top{padding-bottom:0;padding-left:0}.side-nav__item--top:last-child{padding-bottom:var(--space-4xs)}.side-nav__item-list{list-style:none;margin:0 0 var(--space-3xl) 0;padding:0}.side-nav__item-headline{color:var(--color-black);font-size:var(--font-size-h4);font-weight:700;line-height:var(--line-height-h4);margin:0 0 var(--space-s) 0}.side-nav__item-headline-link,.side-nav__link{color:var(--color-black);text-decoration:none}.side-nav__link{align-items:center;background:none;border:0;cursor:pointer;display:flex;justify-content:space-between;margin:0;padding:0;width:100%}.side-nav__link:hover{color:var(--color-black);text-decoration:none}.side-nav__link.focus-visible{color:var(--color-petrol-middle);outline:2px var(--color-petrol-middle) solid}.side-nav__link:focus-visible{color:var(--color-petrol-middle);outline:2px var(--color-petrol-middle) solid}.side-nav__item--logout{padding-left:0}.side-nav__item--logout .side-nav__link{justify-content:flex-start}.side-nav__item--is-active .side-nav__link{color:var(--color-petrol)}.side-nav__item--is-active .icon--arrow{fill:var(--color-petrol)}.side-nav__link:hover .icon--arrow{fill:var(--color-black)}.side-nav__link.focus-visible .icon--arrow{fill:var(--color-petrol-middle)}.side-nav__link:focus-visible .icon--arrow{fill:var(--color-petrol-middle)}@media (hover:hover){.side-nav__link:hover{color:var(--color-petrol)}.side-nav__link:hover .icon--arrow{fill:var(--color-petrol)}}.side-nav__logout{list-style:none;margin:var(--space-xxs) 0 var(--space-xs);padding:0}.side-nav__logout-link{ ...
# 	<style>/*module/quickstartnavigation*/ .quickstart-navigation{background:var(--color-brown-warm-light);margin-bottom:var(--space-xl);margin-left:-2.5rem;padding:var(--space-xs) var(--space-xs) 0 var(--space-xs)}.quickstart-navigation--finance{background:var(--color-petrol-light)}.quickstart-navigation__content{margin-left:var(--space-xxs)}.quickstart-navigation__list{margin-bottom:0}.quickstart-navigation__item:last-child{padding-bottom:var(--space-xs)}.quickstart-navigation__headline{font-size:var(--font-size-h5);line-height:var(--line-height-h5);margin:0 0 var(--space-s)}@media (min-width:64rem){.quickstart-navigation{width:var(--side-nav-width)}}.quickstart-navigation--image .quickstart-navigation__list{-moz-column-gap:var(--space-5xs);column-gap:var(--space-5xs);display:flex;justify-content:space-between;padding-left:0}.quickstart-navigation--image .quickstart-navigation__link{font-size:var(--space-4xs);font-weight:700;line-height:var(--space-3xs);text-align:center;word-break:break-word}.quickstart-navigation--image .quickstart-navigation__item{align-items:center;display:flex;flex:1;flex-direction:column;max-width:6.25rem;padding-left:0}.quickstart-navigation--image .image{border-radius:50%;margin-bottom:var(--space-4xs);width:6.25rem}@media (min-width:64rem){.quickstart-navigation--image{max-width:var(--side-nav-width)}.quickstart-navigation--image .quickstart-navigation__item{max-width:5rem}}</style>
# 	<style>/*module/metanavigation*/ .meta-navigation{border-top:1px solid var(--color-border);display:flex;justify-content:space-between;list-style:none;padding:var(--space-m) 0 0 var(--space-3xs)}.meta-navigation__item{flex:1 1 auto;padding-right:0}.meta-navigation__link{color:var(--color-black);font-size:var(--font-size-text-xsmall);line-height:var(--line-height-text-xsmall)}.meta-navigation__link:hover{color:var(--color-black);text-decoration:none}@media (hover:hover){.meta-navigation__link:hover{color:var(--color-petrol)}}@media (min-width:64rem){.meta-navigation{margin:0;padding:var(--space-3xs) 0}}</style>
# 	<style>/*module/portalnavigation*/ .portal-navigation-wrapper{background-color:var(--color-white);box-shadow:var(--header-box-shadow);color:var(--color-text);pointer-events:auto;position:absolute;transition:transform var(--sticky-transition-time);width:100%;z-index:var(--z-header-portal-navigation)}.portal-navigation-wrapper--extended{box-shadow:none}.header-is-sticky .portal-navigation-wrapper{box-shadow:none;pointer-events:none;transform:translateY(-2.5rem);transition:transform var(--sticky-transition-time)}.portal-navigation-wrapper__inner{align-items:center;background-color:var(--color-white);display:flex;width:100%}.portal-navigation-wrapper--search .portal-navigation-wrapper__inner{display:none}.portal-navigation-wrapper__background-overlay{background:none;cursor:default;height:100vh;left:0;position:absolute;top:0;transition:background var(--transition-time) ease var(--transition-delay),width .1s .75s;width:0;z-index:var(--z-header-portal-navigation-overlay)}.portal-navigation-wrapper--extended .portal-navigation-wrapper__background-overlay{background-color:var(--color-overlay);transition:background var(--transition-time) ease;width:var(--width-viewport)}.portal-navigation-wrapper__separator{background-color:var(--color-border);cursor:default;height:1.5rem;width:1px}.portal-navigation-wrapper__icons{background-color:transparent;border:none;color:var(--color-grey-60);cursor:pointer;padding:var(--space-5xs) var(--width-gutter) var(--space-5xs) .625rem}.portal-navigation-wrapper__cart{display:flex;flex-direction:column;justify-content:center;padding:0 var(--space-3xs);position:relative}.portal-navigation-wrapper__cart-article-wrapper{background:var(--color-petrol-dark);border-radius:100%;display:flex;flex-direction:column;font-size:var(--font-size-watch-list);height:var(--space-3xs);justify-content:center;left:1.875rem;line-height:normal;position:absolute;text-align:center;top:auto;transform:translateY(-50%);width:var(--space-3xs)}.portal-navigation-wrapper__cart-article-wrapper--hidden{display:none}.portal-navigation-wrapper__cart-article-number{color:var(--color-white);font-size:.625rem;font-weight:700}.portal-navigation-wrapper--extended .portal-navigation-wrapper__icons,.portal-navigation-wrapper--extended .portal-navigation-wrapper__separator{display:none}.portal-navigation{flex-grow:1;max-width:100%}.portal-navigation__cart .icon,.portal-navigation__watchlist .icon{height:1.25rem;width:1.25rem}.portal-navigation[open]{height:calc(100vh - var(--header-height))}.portal-navigation[open] summary .icon{transform:rotate(0)}.portal-navigation__header{align-items:center;cursor:pointer;display:flex;justify-content:space-between;padding:.625rem var(--space-4xs) .375rem var(--width-gutter);-webkit-user-select:none;-moz-user-select:none;user-select:none}.portal-navigation[open] .portal-navigation__header{padding-right:var(--width-gutter)}.portal-navigation__header::-webkit-details-marker{display:none}.portal-navigation__title{font-weight:700}.portal-navigation__body{--portal-navigation-header-height:2.5rem;cursor:default;max-height:calc(100svh - var(--header-height) - var(--portal-navigation-header-height));overflow:auto;padding:0 var(--space-xxs) var(--space-5xs) var(--space-xxs)}.portal-navigation__welcome{color:var(--color-grey-60);display:block;font-size:var(--font-size-text-medium);font-weight:700;line-height:var(--line-height-text-medium);overflow:hidden;text-overflow:ellipsis;white-space:nowrap}.portal-navigation__cart{margin-bottom:var(--space-5xs)}.portal-navigation__cart-number,.portal-navigation__watchlist-number{font-weight:700}.portal-navigation__separator-item.portal-navigation__separator{margin:var(--space-6xs) 0}.portal-navigation__separator{background-color:var(--color-border);height:1px;margin-bottom:1.5rem;margin-top:1.5rem;width:100%}.portal-navigation__separator--top{margin-top:1rem}.portal-navigation-mobile--General .portal-navigation__separator--top{margin-top:0}.portal-navigation__list{display:flex;flex-d ...
# 	<style>/*module/genericsection*/ .generic-section[*|\:not-has\(\.generic-section__cell\%20]{display:none}.generic-section:not(:has(.generic-section__cell *)){display:none}.generic-section__inner{list-style:none;margin-bottom:0;padding-left:0}.generic-section__column{margin-bottom:var(--space-xl);padding:0}.generic-section__cell:not(:first-child){margin-top:var(--space-xl)}@media (min-width:48rem){.generic-section__inner{display:flex;flex-wrap:wrap;justify-content:space-between}.generic-section__column{flex:0 0 var(--width-columns-4);margin-bottom:0;max-width:var(--width-columns-4)}.generic-section__column--1-1,.generic-section__column--1-3:nth-child(3){flex:0 0 100%;max-width:100%}.generic-section__column--1-3:nth-child(3){margin-top:var(--width-gutter)}.main--editorial .generic-section__column--1-2,.main--editorial .generic-section__column--1-3,.main--overview .generic-section__column--1-2,.main--overview .generic-section__column--1-3{display:flex;flex-direction:column}.main--editorial .generic-section__column--1-2 .generic-section__cell:first-child:last-child,.main--editorial .generic-section__column--1-3 .generic-section__cell:first-child:last-child,.main--overview .generic-section__column--1-2 .generic-section__cell:first-child:last-child,.main--overview .generic-section__column--1-3 .generic-section__cell:first-child:last-child{display:flex;flex-grow:1}}@media (min-width:64rem){.generic-section__inner{flex-wrap:nowrap}.generic-section__column--1-2{flex:0 0 var(--width-columns-6);max-width:var(--width-columns-6)}.generic-section__column--2-3{flex:0 0 var(--width-columns-8);max-width:var(--width-columns-8)}.generic-section__column--1-3,.generic-section__column--1-3:nth-child(3){flex:0 0 var(--width-columns-4);margin-top:0;max-width:var(--width-columns-4)}}</style>
# 	<style>/*module/imagetext*/ .image-text__image{aspect-ratio:3/2;cursor:pointer;margin-bottom:var(--space-3xs);overflow:hidden}.image-text__link{display:block}.image-text__image--no-aspect-ratio .image{width:auto}.image-text__headline{font-size:var(--font-size-h3);line-height:var(--line-height-h3);margin-bottom:var(--space-4xs)}.image-text__headline--p{font-weight:700}.image-text__meta-text{margin-right:.5rem}.image-text__meta-hint-icon{display:inline-block;margin-right:.25rem;position:relative;width:1.25rem}.image-text__meta-hint-icon .icon{left:0;margin-right:0;position:absolute;top:-1.0625rem}.image-text__meta-hint{color:var(--color-grey-60);display:inline-block;font-weight:400}.image-text__date{color:var(--color-grey-60);font-family:var(--font-family-thebest);font-size:var(--font-size-text-medium)}.image-text__text{cursor:pointer}@media (max-width:47.9375rem){.image-text__image--no-aspect-ratio{aspect-ratio:auto;display:flex;flex-direction:column;justify-content:flex-end}}@media (min-width:48rem){.image-text__image{margin-bottom:var(--space-xs)}}@media (hover:hover){.image-text:hover .image-text__headline{color:var(--color-petrol-middle)}}@media (min-width:48rem) and (max-width:63.9375rem){.generic-section__column--1-3+.generic-section__column--1-3:last-child .image-text--TextBelowImage{display:flex}.generic-section__column--1-3+.generic-section__column--1-3:last-child
# 		.image-text--TextBelowImage
# 		.image-text__image{flex:0 0 calc((100% - var(--width-gutter))/2);margin-bottom:0;margin-right:var(--width-gutter)}}@media (min-width:48rem){.generic-section__column--1-2 .image-text--TextBelowImage .image-text__image--no-aspect-ratio,.generic-section__column--1-3 .image-text--TextBelowImage .image-text__image--no-aspect-ratio{display:flex;flex-direction:column;justify-content:flex-end}@supports not (aspect-ratio:3/2){.generic-section__column--1-2 .image-text--TextBelowImage .image-text__image--no-aspect-ratio,.generic-section__column--1-3 .image-text--TextBelowImage .image-text__image--no-aspect-ratio{position:relative}.generic-section__column--1-2 .image-text--TextBelowImage .image-text__image--no-aspect-ratio:before,.generic-section__column--1-3 .image-text--TextBelowImage .image-text__image--no-aspect-ratio:before{content:"";display:block;height:0;padding-top:66.6666%}.generic-section__column--1-2 .image-text--TextBelowImage .image-text__image--no-aspect-ratio .picture,.generic-section__column--1-3 .image-text--TextBelowImage .image-text__image--no-aspect-ratio .picture{bottom:0;left:0;position:absolute}}}@media (min-width:64rem){.generic-section__column--2-3 .image-text--TextBelowImage .image-text__headline{font-size:var(--font-size-h2);line-height:var(--line-height-h2)}}.image-text--TextInImage .image-text__headline{font-size:var(--font-size-h2);line-height:var(--line-height-h2)}.image-text--TextInImage .image-text__headline.heavy{font-size:var(--font-size-heavy-h2);line-height:var(--line-height-heavy-h2)}@media (min-width:56.25rem){.image-text--TextInImage{position:relative}.image-text--TextInImage .p-title__meta{font-size:1.25rem;line-height:1.375rem}.image-text--TextInImage .image-text__headline{font-size:var(--font-size-h1);line-height:var(--line-height-h1)}.image-text--TextInImage .image-text__headline.heavy{font-size:var(--font-size-heavy-h1);line-height:var(--line-height-heavy-h1)}.image-text--TextInImage .image-text__image{margin:0 0 0 auto;width:var(--width-columns-7)}.image-text--inverted.image-text--TextInImage .image-text__image{margin:0 auto 0 0}.image-text--TextInImage .image-text__content{background-color:var(--color-white);bottom:calc(var(--space-xs)*-1);left:0;max-width:calc(50% + var(--width-gutter)/2);padding:var(--space-xs);padding-left:0;position:absolute;z-index:var(--z-image-text)}.image-text--inverted.image-text--TextInImage .image-text__content{padding-left:var(--space-xs);padding-right:0}.generic-section__column--1-1 .image-text__meta-hint-icon{width:1.5rem}.generic-section__column--1-1 .image-text__meta-hint-icon .icon{height:1.5rem;top:-1.25rem;width:1.5rem}}@media (min-width:56.25rem) and (max-width:63.9375rem){.image-text--inverted.image-text--TextInImage .image-text__content{left:auto;right:0}}@media (min-width:64rem){.image-text--TextInImage .p-title .p-title__meta{font-size:1.25rem;line-height:1.375rem}.image-text--TextInImage .image-text__content,.image-text--inverted.image-text--TextInImage .image-text__content{bottom:0;padding:var(--space-m);padding-left:0}.image-text--inverted.image-text--TextInImage .image-text__content{left:auto;padding-left:var(--space-m);padding-right:0;right:0}.image-text--TextInImage .image-text__image{aspect-ratio:16/9;width:calc(var(--width-columns-10) + var(--width-gutter))}}.image-text--TextBesideImageSmall{align-items:flex-start;display:flex}.image-text--TextBesideImageSmall .image-text__image{aspect-ratio:1/1;flex:0 0 calc(25% - var(--width-gutter)*3/4);margin-bottom:0;margin-right:var(--width-gutter)}.image-text--TextBesideImageSmall .image-text__headline{font-size:var(--font-size-h5);line-height:var(--line-height-h5);margin-bottom:0}.image-text--TextBesideImageSmall .image-text__headline.heavy{font-size:var(--font-size-heavy-h5);line-height:var(--line-height-heavy-h5)}.image-text--TextBesideImageSmall .p-title__meta{font-size:var(--font-size-text-xsmall);line-height:var(--line-height-text-xsmall)}.image-text--TextBesideImageSmall .image-text__text{displ ...
# 	<style>/*module/quickstart*/ .quick-start{overflow:hidden;width:100%}.quick-start__inner{margin:0 auto;max-width:var(--content-max-width)}.quick-start__headline{margin-bottom:var(--space-xl);text-align:center}.quick-start__list-wrapper{background:var(--color-brown-warm-light);padding:var(--space-m) 0}.quick-start__list{grid-gap:var(--space-m) var(--width-gutter);display:grid;grid-template-columns:1fr 1fr;margin:0;padding:0 var(--width-gutter)}.quick-start__inner--themes .quick-start__list{margin-bottom:var(--space-m)}.quick-start__item{cursor:pointer;display:flex;flex-direction:column;padding:0}.quick-start__img-wrapper{align-self:center;max-width:7.5rem;padding-bottom:var(--space-xxs);width:100%}.quick-start__img-wrapper .picture{aspect-ratio:1/1;display:block;position:relative}.quick-start__img-wrapper .picture:before{background:var(--color-white);border-radius:100%;content:"";display:block;height:100%;left:0;opacity:.3;position:absolute;top:0;width:100%}.quick-start__img-wrapper .image{border-radius:100%;position:relative;width:100%}.quick-start__link{text-align:center;text-decoration:none}.quick-start__themes-wrapper{bottom:var(--space-xs);display:flex;justify-content:center;left:var(--width-gutter);position:absolute;width:100%}.quick-start__themes{width:var(--content-max-width)}.quick-start__themes .link{color:var(--color-text);margin-bottom:0}@media (hover:hover){.quick-start__item:hover .quick-start__link .link--plain{color:var(--color-text-hover)}.quick-start__themes .link:hover{color:var(--color-petrol)}.quick-start__themes .link:hover .icon--arrow{fill:var(--color-petrol)}}@media (max-width:22.4375rem){.quick-start__headline{margin-bottom:var(--space-xl)}}@media (max-width:47.9375rem){.quick-start__headline{margin-left:var(--width-gutter);margin-right:var(--width-gutter)}}@media (min-width:48rem){.quick-start__list{gap:var(--space-5xl) var(--space-xl);grid-template-columns:1fr 1fr 1fr}}@media (min-width:64rem){.quick-start__list-wrapper:after,.quick-start__list-wrapper:before{content:" ";height:100%;position:absolute;top:0;width:calc(50vw - 50% + .625rem)}.quick-start__list-wrapper:before{left:.625rem;transform:translateX(-100%)}.quick-start__list-wrapper:after{right:.625rem;transform:translateX(100%)}.quick-start__list-wrapper:first-child:before,.quick-start__list-wrapper:last-child:after{background-color:var(--color-brown-warm-light)}.quick-start__inner{display:flex;position:relative;width:100%}.quick-start__headline{text-align:left}.quick-start__list-wrapper{display:flex;flex-direction:column;padding:var(--width-gutter);width:50%}.quick-start__inner--single .quick-start__list-wrapper{width:100%}.quick-start__list-wrapper:not(.quick-start__inner--single .quick-start__list-wrapper):first-child{padding-right:calc(var(--width-gutter)/2)}.quick-start__list-wrapper:not(.quick-start__inner--single .quick-start__list-wrapper):last-child{padding-left:calc(var(--width-gutter)/2)}.quick-start__list-container{display:flex;flex:1;overflow:hidden;width:100%}.quick-start__inner--themes .quick-start__list-container{margin-bottom:2rem}.quick-start__list{grid-gap:var(--space-m) var(--width-gutter);grid-auto-rows:1fr;grid-template-columns:1fr 1fr;padding:0;width:100%}.quick-start__inner--single .quick-start__list{grid-template-columns:1fr 1fr 1fr 1fr}.quick-start__item{min-width:30%}.quick-start__inner--themes .quick-start__link{margin-bottom:0}.quick-start__themes-wrapper{bottom:2.375rem}}@media (min-width:80rem){.quick-start__list{grid-template-columns:1fr 1fr 1fr}.quick-start__inner--single .quick-start__list{grid-template-columns:1fr 1fr 1fr 1fr 1fr 1fr}}.quick-start__list-wrapper--finance{background:var(--color-petrol-light)}@media (min-width:64rem){.quick-start__list-wrapper--finance:first-child:before,.quick-start__list-wrapper--finance:last-child:after{background-color:var(--color-petrol-light)}}.quick-start__list--slider{grid-template-columns:repeat(6,minmax(0,1fr));overflow-x:hidden;width:calc(285vw - var(--width-gutter)* ...
# 	<style>/*module/sectionheadline*/ .section-headline{border-top:2px solid var(--color-black);font-size:var(--font-size-h6);line-height:var(--line-height-h6);margin:var(--space-l) 0 0;padding:var(--space-5xs) 0 0 0}@media (min-width:48rem){.section-headline{font-size:var(--font-size-h5);line-height:var(--line-height-h5)}}</style>
# 	<style>/*module/shopproductsteaser*/ .shop-products-teaser{--separator-width:calc(var(--width-column)/2*2 + var(--width-gutter)*2);margin:0 auto var(--space-module-bottom);padding-bottom:1.5rem;padding-top:2rem}.generic-section .shop-products-teaser{margin:0}.generic-section__column--1-1 .shop-products-teaser{margin-left:50%;transform:translate(-50%);width:var(--width-viewport)}.shop-products-teaser__wrapper{margin:0 auto;max-width:var(--content-max-width);padding:0 var(--width-gutter)}.generic-section__column--1-1
# .shop-products-teaser__headline,.generic-section__column--2-3
# .shop-products-teaser__headline,.shop-products-teaser--standalone
# .shop-products-teaser__headline{font-size:var(--font-size-h2);line-height:var(--line-height-h2)}.generic-section__column--1-2 .shop-products-teaser__headline,.generic-section__column--1-3 .shop-products-teaser__headline{font-size:var(--font-size-h3);line-height:var(--line-height-h3)}.shop-products-teaser__item-headline{margin-bottom:.5rem}.shop-products-teaser__link{margin-top:1rem}@media (min-width:48rem){.shop-products-teaser__items{display:grid;grid-template-columns:1fr}}@media (min-width:48rem) and (max-width:63.9375rem){.generic-section__column--1-1:not(.does-not-exist)
# 	.shop-products-teaser__items,.generic-section__column--1-3:nth-child(3n)
# 	.shop-products-teaser__items,.shop-products-teaser--standalone:not(.does-not-exist)
# 	.shop-products-teaser__items{-moz-column-gap:var(--space-m);column-gap:var(--space-m);grid-template-columns:repeat(auto-fit,minmax(calc(50% - var(--space-m)/2),1fr))}}@media (min-width:64rem){.shop-products-teaser__link{margin-top:1.25rem}.generic-section__column--1-1 .shop-products-teaser__items,.shop-products-teaser--standalone .shop-products-teaser__items{grid-gap:0;padding:1rem 0}.generic-section__column--1-1 .shop-products-teaser__items--2,.shop-products-teaser--standalone .shop-products-teaser__items--2{grid-template-columns:1fr calc(var(--width-column) + var(--width-gutter)*3) 1fr}.generic-section__column--1-1 .shop-products-teaser__items--3,.shop-products-teaser--standalone .shop-products-teaser__items--3{grid-template-columns:repeat(2,1fr var(--separator-width)) 1fr}.generic-section__column--1-1 .shop-products-teaser__items--4,.shop-products-teaser--standalone .shop-products-teaser__items--4{grid-template-columns:repeat(3,1fr var(--separator-width)) 1fr}.generic-section__column--1-3:nth-child(3n) .shop-products-teaser__items{grid-template-columns:1fr}}@media print{.shop-products-teaser{display:none}}.shop-products-teaser--petrollight{background-color:var(--color-petrol-light)}.shop-products-teaser--warmbrown{background-color:var(--color-brown-warm-light)}.shop-products-teaser--petrollight .shop-products-teaser__headline-meta,.shop-products-teaser--warmbrown .shop-products-teaser__headline-meta{color:var(--color-black)}.shop-products-teaser__item{border-bottom:1px solid var(--color-grey-60);padding:1.5rem 0}.shop-products-teaser__item:first-child{padding-top:1rem}.shop-products-teaser__item:nth-last-child(2){border-bottom:0}.shop-products-teaser__item-wrapper{display:flex;height:100%}.shop-products-teaser__image-wrapper{margin-right:var(--space-xxs)}.shop-products-teaser__image-wrapper .image{max-width:calc(var(--width-column) + var(--width-gutter))}.shop-products-teaser__content{padding-top:2px}.shop-products-teaser__price{font-weight:700;margin-top:1rem}.shop-products-teaser__separator{display:none}@media (min-width:48rem){.shop-products-teaser__image-wrapper .image{max-width:var(--width-columns-2)}.generic-section__column--1-1 .shop-products-teaser__item,.shop-products-teaser--standalone .shop-products-teaser__item{padding-top:1.5rem}.generic-section__column--1-1 .shop-products-teaser__content,.shop-products-teaser--standalone .shop-products-teaser__content{display:flex;flex-direction:column;flex-grow:1;justify-content:space-between;padding-top:2px}.generic-section__column--1-1 .shop-products-teaser__items--2
# 	.shop-products-teaser__item,.generic-section__column--1-1 .shop-products-teaser__items--3
# 	.shop-products-teaser__item:nth-last-of-type(-n+3),.generic-section__column--1-1 .shop-products-teaser__items--4
# 	.shop-products-teaser__item:nth-last-of-type(-n+5),.generic-section__column--1-2 .shop-products-teaser__item:nth-last-child(2),.generic-section__column--1-3 .shop-products-teaser__item:nth-last-child(2),.generic-section__column--2-3 .shop-products-teaser__item:nth-last-child(2),.shop-products-teaser--standalone .shop-products-teaser__items--2
# 	.shop-products-teaser__item,.shop-products-teaser--standalone .shop-products-teaser__items--3
# 	.shop-products-teaser__item:nth-last-of-type(-n+3),.shop-products-teaser--standalone .shop-products-teaser__items--4
# ...
#               </li>
#
#               <li class="footer__column-item">
#                 <a class="link footer__link link--white" href="/rss/" data-track-value="footer_inhalt.rss">RSS Feed</a>
#               </li>
#
#           </ul>
#         </div>
#
#           <div class="footer__column">
#             <p role="heading" aria-level="3" id="column-4" class="h6 footer__column-title">Abo &amp; Flatrate</p>
#             <ul aria-labelledby="column-3" class="p-list--plain">
#
#                 <li class="footer__column-item">
#                   <a class="link footer__link link--white" href="/abo/print/" data-track-value="footer_abo.printabos">Print-Abos</a>
#                 </li>
#
#                 <li class="footer__column-item">
#                   <a class="link footer__link link--white" href="/abo/digital/" data-track-value="footer_abo.digitalabos">Digital-Abos</a>
#                 </li>
#
#                 <li class="footer__column-item">
#                   <a class="link link--external footer__link link--white" href="https://abo-serviceportal.stiftung-warentest.de/s/" data-track-value="footer_abo.verwalten">Abo verwalten</a>
#                 </li>
#
#                 <li class="footer__column-item">
#                   <a class="link link--external footer__link link--white" href="https://abo-serviceportal.stiftung-warentest.de/s/contactsupport?contactReason=K%C3%BCndigung&amp;DPV_Kuendigung__c=mit%20Anschrift" data-track-value="footer_abo.k&#252;ndigen">Abo kündigen</a>
#                 </li>
#
#                 <li class="footer__column-item">
#                   <a class="link footer__link link--white" href="/meintest/aboflatrate/kuendigen/ordentlich/" data-track-value="footer_abo.flatrate.k&#252;ndigen">Flatrate kündigen</a>
#                 </li>
#
#             </ul>
#           </div>
#
#
#           <div class="footer__column">
#             <p role="heading" aria-level="3" id="column-5" class="h6 footer__column-title">Kundenservice</p>
#             <ul aria-labelledby="column-3" class="p-list--plain">
#
#                 <li class="footer__column-item">
#                   <a class="link footer__link link--white" href="/kontakt/" data-track-value="footer_service.kontakt">Kontakt</a>
#                 </li>
#
#                 <li class="footer__column-item">
#                   <a class="link footer__link link--white" href="/Hilfe-5836822-0/" data-track-value="footer_service.hilfe">Hilfe</a>
#                 </li>
#
#                 <li class="footer__column-item">
#                   <a class="link footer__link link--white" href="/Hilfe-5836822-5313970/" data-track-value="footer_service.lieferung">Lieferung &amp; Zahlung</a>
#                 </li>
#
#                 <li class="footer__column-item">
#                   <a class="link footer__link link--white" href="/Hilfe-5836822-6060974/" data-track-value="footer_service.fernabsatzrecht.digitalinhalt">Fernabsatzrecht für digitale Inhalte</a>
#                 </li>
#
#                 <li class="footer__column-item">
#                   <a class="link footer__link link--white" href="/Hilfe-5836822-6158741/" data-track-value="footer_service.fernabsatzrecht.zeitschriftabo">Fernabsatzrecht für Zeitschriften-Abonnements</a>
#                 </li>
#
#                 <li class="footer__column-item">
#                   <a class="link footer__link link--white" href="/Hilfe-5836822-6158749/" data-track-value="footer_service.fernabsatzrecht.buchheftcd">Fernabsatzrecht für Bücher, Hefte und CD-Roms</a>
#                 </li>
#
#             </ul>
#           </div>
#
#       </div>
#       <div class="footer__social">
#         <p role="heading" aria-level="3" id="social-media" class="visually-hidden">Social Media</p>
#         <ul aria-labelledby="social-media" class="p-list--plain footer__social-list">
#
#             <li class="footer__social-item">
#               <a class="link link--external footer__social-link link--plain" href="https://www.facebook.com/stiftungwarentest/" data-track-value="footer_socialmedia" rel="noopener noreferrer" target="_blank" data-icon="social-facebook" aria-label="test.de auf Facebook">
#                 <svg aria-hidden="true" role="img" class="icon icon--social-facebook" data-icon="social-facebook"><use class="icon__use" xlink:href="#ic_social-facebook"></use></svg>
#               </a>
#             </li>
#
#             <li class="footer__social-item">
#               <a class="link link--external footer__social-link link--plain" href="https://www.instagram.com/stiftungwarentest" data-track-value="footer_socialmedia" rel="noopener noreferrer" target="_blank" data-icon="social-instagram" aria-label="test.de auf Instagram">
#                 <svg aria-hidden="true" role="img" class="icon icon--social-instagram" data-icon="social-instagram"><use class="icon__use" xlink:href="#ic_social-instagram"></use></svg>
#               </a>
#             </li>
#
#             <li class="footer__social-item">
#               <a class="link link--external footer__social-link link--plain" href="https://twitter.com/warentest" data-track-value="footer_socialmedia" rel="noopener noreferrer" target="_blank" data-icon="social-x" aria-label="test.de auf Twitter">
#                 <svg aria-hidden="true" role="img" class="icon icon--social-x" data-icon="social-x"><use class="icon__use" xlink:href="#ic_social-x"></use></svg>
#               </a>
#             </li>
#
#             <li class="footer__social-item">
#               <a class="link link--external footer__social-link link--plain" href="https://www.youtube.com/user/stiftungwarentest" data-track-value="footer_socialmedia" rel="noopener noreferrer" target="_blank" data-icon="social-youtube" aria-label="test.de auf Youtube">
#                 <svg aria-hidden="true" role="img" class="icon icon--social-youtube" data-icon="social-youtube"><use class="icon__use" xlink:href="#ic_social-youtube"></use></svg>
#               </a>
#             </li>
#
#         </ul>
#       </div>
#
#     <div class="footer__extra">
#       <ul class="p-list--plain footer__row">
#
#           <li class="footer__row-item">
#             <a class="link footer__link link--white" href="/datenschutz/" data-track-value="footer_legal">Datenschutz</a>
#           </li>
#
#           <li class="footer__row-item">
#             <a class="link footer__link link--white" href="/cookie-richtlinie/" data-track-value="footer_legal">Cookie Richtlinie</a>
#           </li>
#
#           <li class="footer__row-item">
#             <a class="link footer__link link--white" href="/Hilfe-5836822-5313970/" data-track-value="footer_legal">AGB</a>
#           </li>
#
#           <li class="footer__row-item">
#             <a class="link footer__link link--white" href="/impressum/" data-track-value="footer_legal">Impressum</a>
#           </li>
#
#           <li class="footer__row-item">
#             <a class="link link--external footer__link link--white" href="https://www.test.de/#cmpscreen" data-track-value="footer_legal">Widerruf Cookie-Einwilligung</a>
#           </li>
#
#       </ul>
#       <p class="footer__copyright">© Stiftung Warentest. Alle Rechte vorbehalten.</p>
#     </div>
#   </div>
# </footer>
#
#
#
#     </div>
# 	<style>/*utilities*/ .hidden{display:none}.visually-hidden{height:1px;left:-625rem;overflow:hidden;position:absolute;top:auto;width:1px}.white-space{white-space:nowrap}@media print{@page{size:auto;margin:15mm 25mm}html{font-size:12pt}.main__primary,body{background-color:var(--color-white)!important;box-shadow:none!important}p{orphans:2;widows:3}h1,h2,h3,h4,h5,h6{-moz-column-break-after:avoid;break-after:avoid;page-break-after:avoid;page-break-inside:avoid}.cmpboxrecall.cmpstyleroot{display:none}.link{color:var(--color-text)!important;text-decoration:none!important}}[v-cloak]{display:none}body{overflow:visible!important;overflow:initial!important}.no-scroll body{overflow:hidden!important}.tp-modal .tp-close{background-image:url("data:image/svg+xml;charset=utf-8,%3Csvg%20width='20'%20height='20'%20fill='none'%20xmlns='http://www.w3.org/2000/svg'%3E%3Cpath%20d='m13.51%207.208-.706-.708-2.798%202.798L7.207%206.5l-.707.707%202.798%202.799L6.503%2012.8l.707.707%202.796-2.795%202.792%202.792.707-.707-2.792-2.792%202.798-2.798z'%20fill='%23000'/%3E%3C/svg%3E")!important}.tp-modal .tp-close:focus{border:0!important;outline:2px solid var(--color-petrol-light);outline-offset:2px}.tp-modal-open{height:auto!important}.tp-modal iframe.focus-visible{outline:.25rem solid var(--color-petrol-light);outline-offset:2px}.tp-modal iframe.focus-visible,.tp-modal iframe:focus-visible{outline:.25rem solid var(--color-petrol-light);outline-offset:2px}</style>
#     <div class="icon-sprite"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><defs><symbol viewBox="0 -960 960 960" id="ic_add"><path d="M440-440H200v-80h240v-240h80v240h240v80H520v240h-80z" /></symbol><symbol viewBox="0 0 24 24" id="ic_add-circle"><path fill="none" d="M0 0h24v24H0z" /><path d="M12 2C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2m5 11h-4v4h-2v-4H7v-2h4V7h2v4h4z" /></symbol><symbol viewBox="0 -960 960 960" id="ic_album"><path d="M480-300q75 0 127.5-52.5T660-480t-52.5-127.5T480-660t-127.5 52.5T300-480t52.5 127.5T480-300m0-140q-17 0-28.5-11.5T440-480t11.5-28.5T480-520t28.5 11.5T520-480t-11.5 28.5T480-440m0 360q-83 0-156-31.5T197-197t-85.5-127T80-480t31.5-156T197-763t127-85.5T480-880t156 31.5T763-763t85.5 127T880-480t-31.5 156T763-197t-127 85.5T480-80m0-80q134 0 227-93t93-227-93-227-227-93-227 93-93 227 93 227 227 93m0-320" /></symbol><symbol viewBox="0 0 24 24" id="ic_alert_form"><path d="M12 2C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2m1 15h-2v-2h2zm0-4h-2V7h2z" /></symbol><symbol viewBox="0 -960 960 960" id="ic_arrow"><path d="M480-528 296-344l-56-56 240-240 240 240-56 56z" /></symbol><symbol viewBox="0 0 24 24" id="ic_arrow_forward"><path fill="none" d="M0 0h24v24H0z" /><path d="M5 13h11.17l-4.88 4.88c-.39.39-.39 1.03 0 1.42s1.02.39 1.41 0l6.59-6.59a.996.996 0 0 0 0-1.41l-6.58-6.6a.996.996 0 1 0-1.41 1.41L16.17 11H5c-.55 0-1 .45-1 1s.45 1 1 1" /></symbol><symbol viewBox="0 0 24 24" id="ic_autorenew"><path d="M11.56 8.44V6.36c-2.96 0-5.1 2.26-5.1 5.24 0 1.18.34 2.3.94 3.12l-1.92 1.44C4.5 14.88 4 13.3 4 11.6c0-4.3 3.26-7.52 7.56-7.52V2l4.14 3.22zm0 10.68v2.08l-4.14-3.22 4.14-3.22v2.08c2.96 0 5.1-2.26 5.1-5.24 0-1.18-.34-2.3-.94-3.12l1.92-1.44c.98 1.28 1.48 2.86 1.48 4.56 0 4.3-3.26 7.52-7.56 7.52" /></symbol><symbol viewBox="0 -960 960 960" id="ic_barchart"><path d="M80-120v-80h800v80zm40-120v-280h120v280zm200 0v-480h120v480zm200 0v-360h120v360zm200 0v-600h120v600z" /></symbol><symbol viewBox="0 0 24 24" id="ic_beobachten"><path d="M3 11.62C5.32 6.94 8.66 5 12.02 5s6.7 1.94 9.02 6.62c-2.32 4.7-5.66 6.62-9.02 6.62S5.32 16.32 3 11.62m4.24 0c0 2.82 2.18 4.82 4.78 4.82 2.64 0 4.8-2 4.8-4.82s-2.16-4.82-4.8-4.82c-2.6 0-4.78 2-4.78 4.82m4.78 3.28c-1.76 0-3.16-1.32-3.16-3.28 0-.1 0-.18.02-.28 1.04-.16 2.08-.12 3.14.08-.14-1.36-.64-2.22-1.62-2.66.48-.26 1.04-.4 1.62-.4 1.8 0 3.18 1.3 3.18 3.26s-1.38 3.28-3.18 3.28" /></symbol><symbol viewBox="0 0 24 24" id="ic_book_closed"><path d="M7.5 22a3.37 3.37 0 0 1-2.475-1.025A3.37 3.37 0 0 1 4 18.5v-13q0-1.45 1.025-2.475A3.37 3.37 0 0 1 7.5 2H20v15q-.625 0-1.062.438A1.45 1.45 0 0 0 18.5 18.5q0 .625.438 1.063Q19.375 20 20 20v2zM6 15.325q.35-.175.725-.25T7.5 15H8V4h-.5q-.625 0-1.062.438A1.45 1.45 0 0 0 6 5.5zM10 15h8V4h-8zm-2.5 5h9.325q-.15-.35-.238-.712a3.4 3.4 0 0 1-.087-.788q0-.4.075-.775t.25-.725H7.5q-.65 0-1.075.438A1.47 1.47 0 0 0 6 18.5q0 .65.425 1.075T7.5 20" /></symbol><symbol viewBox="0 0 28 28" id="ic_book_preview"><path d="M14 23.332a11.2 11.2 0 0 0-3.033-1.72 9.6 9.6 0 0 0-3.384-.613q-1.72 0-3.325.54-1.605.538-3.091 1.414V6.473a9 9 0 0 1 3.047-1.4 14 14 0 0 1 3.37-.408q1.69 0 3.324.438Q12.543 5.54 14 6.415v14.117a12.7 12.7 0 0 1 3.077-1.385q1.619-.482 3.34-.482a12.2 12.2 0 0 1 4.083.7v-14q.612.204 1.21.467t1.123.642v16.479a16.4 16.4 0 0 0-3.091-1.415 10.4 10.4 0 0 0-3.326-.54 9.6 9.6 0 0 0-3.383.613Q15.4 22.224 14 23.332m2.333-5.833V6.415L22.167.582v11.667zm-4.666 1.896V7.845a11 11 0 0 0-1.998-.628A10 10 0 0 0 7.583 7q-1.05 0-2.085.204-1.036.204-1.998.612v11.58a10.7 10.7 0 0 1 2.012-.555 12 12 0 0 1 2.071-.175q1.05 0 2.071.175 1.02.176 2.012.555" /></symbol><symbol viewBox="0 0 24 24" id="ic_bookmark"><path fill="none" d="M0 0h24v24H0z" /><path d="M19 3H5v18l7-3 7 3z" /></symbol><symbol viewBox="0 -960 960 960" id="ic_car"><path d="M240-200v40q0 17-11.5 28.5T200-120h-40q-17 0-28.5-11.5T120-160v-320l84-240q6-18 21.5-29t34.5-11h440q19 0 34.5 11t21.5 29l84 240v320q0 17-11.5 28.5T800-120h-40q-17 0-28.5-11.5T7 ...
#
#
#
#
# <script>
#
#     var tp = window.tp || [];
#
#     tp.push(["setUseTinypassAccounts", false]);
#     tp.push(["setUsePianoIdUserProvider", false ]);
#     tp.push(["setUsePianoIdLiteUserProvider", true]);
#     tp.push(['setPianoIdUrl', 'https://id-eu.piano.io/']);
#
#     // moved to /js/inline/piano.js
#     // tp.push(["setExternalJWT", ""]);
#
#     if (window.location.search.indexOf('piano-debug=true') !== -1) {
#         tp.push(['setDebug', true]);
#     }
#
#
#
#
#     tp.push(['setTags', ['IsRelaunch','Stiftung Warentest | Unabhängig. Objektiv. Unbestechlich.']]);
#
#
#
#
#         tp.push(['setCustomVariable', 'YearlyFlatrateUrl', '/abo/digital/flat-365/']);
#
#         tp.push(['setCustomVariable', 'MonthlyFlatrateUrl', '/abo/digital/flat/']);
#
#
#
#
#         tp.push(['setCustomVariable', 'hasAccess', 'false']);
#
#
# </script>
#
# <script src="//experience-eu.piano.io/xbuilder/experience/load?aid=lzfikWNGpe" defer></script>
#
#
#
#
#     <script src="https://cdn.test.de/static/scripts/main.min;v128175272.js" defer></script>
#     <script type="application/ld+json">
# {"@context":"https://schema.org","@type":"WebSite","url":"https://www.test.de/","potentialAction":{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://www.test.de/suche/?q={search_term_string}"},"query-input":"required name=search_term_string"},"author":[],"publisher":{"@type":"Organization","name":"Stiftung Warentest"}}
# </script>
#
#
# <!-- Mapp -->
# <script>
# <!--
# var SWTDL = new Object();
# SWTDL.seite = new Array();
# SWTDL.seite.name = "start";
# SWTDL.seite.start = "start";
# SWTDL.seite.ressort = "";
# SWTDL.seite.kategorie = "";
# SWTDL.seite.themen = "";
# SWTDL.seite.dachzeileTitel = "Stiftung Warentest | Unabhängig. Objektiv. Unbestechlich.";
# SWTDL.seite.plattform = "web";
# SWTDL.seite.seitentyp = "start";
# SWTDL.produkt = new Array();
# SWTDL.user = new Array();
# SWTDL.user.meintestLogin = "nicht eingeloggt";
# SWTDL.user.flatratestatus = "ohne";
# SWTDL.user.flatratkuendigung = "ohne";
# SWTDL.user.abostatus = "ohne";
# SWTDL.testab = new Array();
# SWTDL.suche = new Array();
# SWTDL.bestellung = new Array();
# SWTDL.flatrate = new Array();
# -->
# </script>
# <script src="https://cdn.test.de/static/scripts/mapp/mapp-live.min;v128175272.js" defer></script>
# <!-- /Mapp -->
#
# <script type="text/javascript">var temporaryPianoEvents = window.temporaryPianoEvents = window.temporaryPianoEvents || [];
# temporaryPianoEvents.push({
#   "event": "page.display",
#   "page": "start",
#   "page_filter": [],
#   "cms_link": "cms://ps4/overviewpagebase/default/?pool=online",
#   "directory": "start",
#   "page_reload": window.pageHasBeenReloaded,
#   "single_product_id": "",
#   "thema_ressort": [],
#   "related_themenseite": [],
#   "information_type": "",
#   "info_site": false,
#   "title": "Stiftung Warentest | Unabhängig. Objektiv. Unbestechlich.",
#   "position_payment_interface": "",
#   "login_status": "nicht eingeloggt",
#   "subs_magazine_type": "ohne",
#   "subs_flatrate_type": "ohne",
#   "subs_flatrate_cancellation": "ohne"
# });
# temporaryPianoEvents.push({
#   "event": "Transaction Finish"
# });
# </script>
# </body>
# </html>

# %%
HTTP/3 (QUIC)
HTTP/3 основан на протоколе QUIC, который был разработан Google и использует UDP вместо TCP. Основные особенности:
•	Быстрое установление соединения: QUIC объединяет установление соединения и шифрование TLS 
в один шаг, что значительно ускоряет время установления соединения.
•	Устранение проблемы блокировки «головы линии»: Поскольку QUIC использует UDP, он не страдает от
блокировки «головы линии» на уровне транспортного протокола.
•	Встроенное шифрование: QUIC всегда зашифрован, что улучшает безопасность.
•	Миграция соединений: QUIC поддерживает изменение IP-адресов и портов, что полезно для мобильных 
пользователей, переходящих между сетями.

# %%
Пример простого HTTP/3 запроса аналогичен HTTP/2 с использованием QUIC:

# %%
| **Характеристика**        | **HTTP 1.1**                     | **HTTP/2**                      | **HTTP/3 (QUIC)**              |
|---------------------------|----------------------------------|---------------------------------|--------------------------------|
| **Транспортный протокол** | TCP                              | TCP                             | QUIC                           |
| **Мультиплексирование**   | Нет                              | Да                              | Да                             |
| **Сжатие заголовков**     | Нет                              | HPACK                           | QPACK                          |
| **Поддержка потоков**     | Нет                              | Да                              | Да                             |
| **Очередь запросов**      | "Head-of-line" блокировка        | Нет                             | Нет                            |
| **Безопасность**          | TLS (отдельно)                   | TLS (встроено)                  | TLS 1.3 (встроено)             |
| **Эффективность**         | Более низкая                     | Более высокая                   | Высокая                        |
| **Поддержка приоритета**  | Нет                              | Да                              | Да                             |
| **Время установления**    | Дольше (TCP + TLS handshake)     | Дольше (TCP + TLS handshake)    | Быстрее (объединенный handshake) |
| **Совместимость**         | Широко поддерживается            | Широко поддерживается           | Требуется поддержка сервером   |
| **Основное использование**| Традиционные веб-страницы        | Более сложные веб-приложения    | Высокопроизводительные веб-приложения |

# %%
WebSockets — это протокол связи, предоставляющий каналы полного дуплекса по единому TCP-соединению.
Он предназначен для использования в веб-приложениях для облегчения взаимодействия в реальном времени
    между клиентом и сервером. WebSockets позволяют открывать постоянные соединения между сервером и
    клиентом, что позволяет обоим сторонам отправлять данные в любое время.
Основные особенности WebSockets:
•	Полный дуплекс: Оба конца соединения (клиент и сервер) могут отправлять данные одновременно.
•	Меньшие накладные расходы: После установления соединения WebSocket, данные могут передаваться 
    с меньшими накладными расходами по сравнению с HTTP.
•	Поддержка событий: Обеспечивает простое и эффективное управление событиями.
Пример реализации WebSocket сервера и клиента

# %%
import asyncio
import websockets

async def echo(websocket, path):
    try:
        async for message in websocket:
            print(message)
            await websocket.send("echo")
    except websocket.exceptions.ConnectionClosed:
        pass

async def main():
    async with websockets.serve(echo, 'localhost', 7676)
    await asyncio.Future()

asyncio.run(main())
        


import asyncio
import websockets

async def send_message():
    uri = "ws://localhost:7676"

    async with websockets.connect(url) as websocket:
        await websocket.send("dgdrfg")
        response = await websocket.recv()

asyncio.run(send_message())

# %%
Преимущества использования WebSockets
•	Мгновенное взаимодействие: WebSockets идеально подходят для приложений, где требуется 
взаимодействие в реальном времени, например, чаты, онлайн-игры, финансовые панели.
•	Экономия ресурсов: После установления соединения WebSocket, обе стороны могут обмениваться данными 
без повторных запросов HTTP, что экономит ресурсы и уменьшает задержки.
•	Простота использования: Поддерживается большинством современных веб-браузеров и серверных технологий.
Недостатки и проблемы
•	Совместимость с устаревшими системами: Некоторые старые системы и прокси-серверы могут не поддерживать WebSockets.
•	Безопасность: Постоянные соединения могут быть уязвимы для атак, таких как DoS. Важно внедрять меры 
безопасности, такие как проверка подлинности и шифрование.
•	Ограничения сети: Некоторые корпоративные сети и брандмауэры могут блокировать WebSocket соединения.

# %%
HTTP клиент на Python с использованием requests

# %%
   import requests

class HttpClient:
    def __init__(self, base_url, headers=None, timeout=10):
        """
        Инициализация HTTP клиента.
        
        :param base_url: Базовый URL для запросов
        :param headers: Заголовки по умолчанию
        :param timeout: Таймаут для запросов (в секундах)
        """
        self.base_url = base_url.rstrip('/')
        self.headers = headers or {}
        self.timeout = timeout

    def get(self, endpoint, params=None, headers=None):
        """
        Выполняет GET-запрос.
        
        :param endpoint: Конечная точка API
        :param params: Параметры запроса
        :param headers: Заголовки для этого запроса
        :return: Ответ в формате JSON
        """
        url = f"{self.base_url}/{endpoint.lstrip('/')}"
        response = requests.get(url, params=params, headers={**self.headers, **(headers or {})}, timeout=self.timeout)
        response.raise_for_status()  # Генерирует исключение для HTTP ошибок
        return response.json()

    def post(self, endpoint, data=None, json=None, headers=None):
        """
        Выполняет POST-запрос.
        
        :param endpoint: Конечная точка API
        :param data: Данные формы
        :param json: JSON данные
        :param headers: Заголовки для этого запроса
        :return: Ответ в формате JSON
        """
        url = f"{self.base_url}/{endpoint.lstrip('/')}"
        response = requests.post(url, data=data, json=json, headers={**self.headers, **(headers or {})}, timeout=self.timeout)
        response.raise_for_status()
        return response.json()

    def put(self, endpoint, data=None, json=None, headers=None):
        """
        Выполняет PUT-запрос.
        
        :param endpoint: Конечная точка API
        :param data: Данные формы
        :param json: JSON данные
        :param headers: Заголовки для этого запроса
        :return: Ответ в формате JSON
        """
        url = f"{self.base_url}/{endpoint.lstrip('/')}"
        response = requests.put(url, data=data, json=json, headers={**self.headers, **(headers or {})}, timeout=self.timeout)
        response.raise_for_status()
        return response.json()

    def delete(self, endpoint, headers=None):
        """
        Выполняет DELETE-запрос.
        
        :param endpoint: Конечная точка API
        :param headers: Заголовки для этого запроса
        :return: Ответ в формате JSON
        """
        url = f"{self.base_url}/{endpoint.lstrip('/')}"
        response = requests.delete(url, headers={**self.headers, **(headers or {})}, timeout=self.timeout)
        response.raise_for_status()
        return response.json()


# Использование
if __name__ == "__main__":
    client = HttpClient(base_url="https://jsonplaceholder.typicode.com", headers={"User-Agent": "HttpClientExample"})

    # GET запрос
    response = client.get("/posts", params={"userId": 1})
    print("GET Response:", response)

    # POST запрос
    new_post = {"title": "foo", "body": "bar", "userId": 1}
    response = client.post("/posts", json=new_post)
    print("POST Response:", response)

    # PUT запрос
    updated_post = {"id": 1, "title": "foo", "body": "bar", "userId": 1}
    response = client.put("/posts/1", json=updated_post)
    print("PUT Response:", response)

    # DELETE запрос
    response = client.delete("/posts/1")
    print("DELETE Response:", response)

# %%
Архитектура веб-серверов может сильно различаться в зависимости от требований к производительности, 
масштабируемости, надежности и гибкости. Рассмотрим основные виды архитектур веб-серверов:
1. Однопоточная архитектура (Single-threaded)
В однопоточной архитектуре сервер обрабатывает все запросы последовательно, один за другим.
Преимущества:
•	Простота реализации и отладки.
•	Подходит для простых приложений с низкой нагрузкой.
Недостатки:
•	Низкая производительность при высокой нагрузке.
•	Непригодна для обработки большого количества одновременных запросов.
2. Многопоточная архитектура (Multi-threaded)
В многопоточной архитектуре сервер создает новый поток для каждого входящего запроса.
Преимущества:
•	Улучшенная производительность по сравнению с однопоточной архитектурой.
•	Возможность обработки большого количества одновременных запросов.
Недостатки:
•	Увеличенные накладные расходы на создание и управление потоками.
•	Потенциальные проблемы с безопасностью и управлением памятью.
3. Асинхронная архитектура (Asynchronous)
В асинхронной архитектуре сервер использует неблокирующие операции ввода-вывода и событи
я для обработки запросов, что позволяет одному потоку обрабатывать множество запросов.
Преимущества:
•	Высокая производительность и масштабируемость.
•	Эффективное использование ресурсов.
Недостатки:
•	Сложность реализации и отладки.
•	Возможные проблемы с управлением состояниями и синхронизацией.
4. Архитектура с использованием процессов (Process-based)
В такой архитектуре сервер создает новый процесс для каждого запроса. Это обеспечивает полную изоляцию запросов друг от друга.
Преимущества:
•	Хорошая изоляция и безопасность между запросами.
•	Стабильность и отказоустойчивость.
Недостатки:
•	Высокие накладные расходы на создание процессов.
•	Ограниченная производительность по сравнению с потоками и асинхронными моделями.
5. Архитектура на основе событий (Event-driven)
Сервер обрабатывает запросы с использованием цикла событий, реагируя на события и вызовы обратных функций.
Преимущества:
•	Высокая производительность и масштабируемость.
•	Эффективное использование ресурсов.
Недостатки:
•	Сложность реализации и отладки.
•	Меньшая гибкость по сравнению с многопоточными моделями.
6. Микросервисная архитектура (Microservices)
В микросервисной архитектуре приложение разбито на множество мелких, независимых сервисов, каждый из которых выполняет свою задачу.
Преимущества:
•	Высокая гибкость и масштабируемость.
•	Легкость в обновлении и развертывании отдельных компонентов.
•	Улучшенная отказоустойчивость.
Недостатки:
•	Усложнение управления и координации между сервисами.
•	Потенциальные накладные расходы на межсервисное взаимодействие.
7. Архитектура с балансировкой нагрузки (Load Balanced)
В такой архитектуре используется один или несколько балансировщиков нагрузки для распределения запросов между несколькими серверами.
Преимущества:
•	Высокая масштабируемость и отказоустойчивость.
•	Эффективное распределение нагрузки.
Недостатки:
•	Сложность настройки и управления.
•	Необходимость дополнительных ресурсов для балансировки нагрузки.
8. Serverless (безсерверная) архитектура
В безсерверной архитектуре разработчики пишут функции, которые развертываются в облаке и 
вызываются по запросу, при этом управление серверами полностью передается провайдеру облачных услуг.
Преимущества:
•	Высокая масштабируемость.
•	Отсутствие необходимости управления серверами.
•	Оплата только за фактическое использование ресурсов.
Недостатки:
•	Ограничения по времени выполнения и объему ресурсов.
•	Зависимость от конкретного провайдера облачных услуг.

# %%
#async serer, client
#1. server

import asyncio
async def handle_client(reader, writer):
    while True:
        data = await reader.read(100)
        if not data:
            break
        message = data.decode()
        response = "response"
        writer.write(response.encode())
        await writer.drain()
    write.close()
    await writer.wait_closed()


async def main():
    server = await asyncio.start_server(handle_client, 'localhost', 8080)
    addr = server.sockets[0].getsockname()
    print(f"server is listening on {addr}")

    async with server:
        await server.server_forever()

asyncio.run(main())


#2. client
import asyncio

async def tcp_client(message):
    reader, writer = await asyncio.open_connection('lcoalhost', 8080)

    writer.write(message.encode())
    await writer.drain()

    data = await reader.read(100)
    writer.close()
    await writer.wait_closed()

message = "segd"
asyncio.run(tcp_client(message))

# %%
ДЗ, шаблон

# %%
import socket
import threading
import os

HOST = "localhost"
PORT = 8080
DOCUMENT_ROOT='./www'
def handle_request(client_socket):
    try:
        # 1. get request
        # 2. get hedares
        # 3. split headers to methoods
        # 4. give back response
        if method in ['GET', 'HEAD']:
            #create response ans send it back
            return
    finally:
        client_socket.close()

def start_server():
    #1. create socket
    #2. bind socket to address and port
    #3. in while loop create threads with fucntion for handle_request

if __name__ == "__main__":
    start_server()

sh ab -n 1000 -c 10 http://localhost:8080/index.html
wrk -t12 -c400 -d30s http://localhost:8080/index.html
